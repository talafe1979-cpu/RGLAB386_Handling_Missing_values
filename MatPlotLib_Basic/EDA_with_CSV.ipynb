# %% [markdown]
# # EDA WITH CSV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '386_PYTHON-PANDAS (3.14.4) (Python 3.14.4)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
